# %% [markdown]
# The primary goal in web automation has always been to create tools that don't break when websites change.
#
# Foundational frameworks, with Selenium being the most notable, work by following direct commands. A developer writes a script with explicit, step-by-step instructions for the browser to follow. For example, a command might be, "find an element using its specific XPath or CSS selector," followed by another command to "click on it" or "type into it."
#
# The fundamental weakness of this method is its brittleness. Websites are dynamic; their underlying code structure, the Document Object Model (DOM), is frequently updated by developers. Even a minor code change, like altering an element's ID or adjusting the page layout, can cause the script's selector to fail.
#
# Once a selector breaks, the script cannot find its target element, and the entire automated process grinds to a halt. This creates a high maintenance burden, as scripts must be constantly fixed to keep up with website updates.

# %% [markdown]
# What if you could give a brain to your browser?

# %% [markdown]
# # **Browser Agents**

# %% [markdown]
# An AI browser agent is a software program enhanced with artificial intelligence that can perform web-based tasks autonomously, much like a human user would. These agents operate within a web browser, using LLMs, and computer vision to interact with websites in a way that mimics human behavior.
#
# Instead of following a rigid, pre-written script like traditional automation tools, an AI browser agent is given a high-level goal in natural language, such as "Find the top tech articles today" or "Book the cheapest flight to New York". The agent then independently plans and executes the steps needed to achieve that goal.

# %% [markdown]
# ## **How AI Browser Agents Work**
#
# An AI browser agent's architecture allows it to perceive, reason, and act within a web environment:
# *   **Perception (The "Eyes")** The agent "sees" a webpage using a combination of methods. It analyzes the structural data, like the HTML or Document Object Model (DOM), to understand the page's layout and identify interactive elements. It also uses computer vision to analyze screenshots, allowing it to identify elements based on their appearance, just as a person would. This dual approach makes it more resilient to website changes.
#
# *   **Reasoning (The "Brain")** At its core is a Large Language Model (LLM), like GPT-4, which acts as the decision-making engine. The LLM interprets the user's goal, analyzes the data from the perception layer, and breaks the task down into a sequence of actions.
#
# *   **Actuation (The "Hands")** To perform actions like clicking, typing, and scrolling, the agent uses an underlying browser automation framework, such as Playwright or Selenium. The LLM decides *what* to do, and the framework executes *how* to do it.
#
# This process repeats in an "observe-decide-act" loop until the task is complete.

# %% [markdown]
# ## **Key Capabilities and Use Cases**
#
# AI browser agents are designed to handle dynamic and complex web interactions. Their primary functions include:
# *   **Web Scraping and Data Extraction** They can navigate multiple pages to extract and structure information, such as product details or contact lists.
# *   **Form Filling and Submission** Agents can intelligently fill out complex forms for tasks like signing up for services, applying for jobs, or getting insurance quotes.
# *   **Cross-Application Workflows** They can automate tasks that span multiple websites, such as taking a new follower from LinkedIn and adding them as a lead in Salesforce.
# *   **Complex Research** An agent can be tasked with open-ended research, like reading a CV, finding relevant jobs online, and saving them to a file.

# %% [markdown]
# # DON'T TRY TO RUN BROWSER-USE IN GOOGLE COLAB

# %% [markdown]
# ## Installation
# ```python
# pip install playwright && playwright install chromium --with-deps
# pip install browser-use
# ```

# %% [markdown]
# ## Setup your LLM
#
# Create a .env file and add your API key. Start with a [free Gemini key](https://aistudio.google.com/app/u/1/apikey?pli=1).
#
# ```bash
# touch .env
# ```
#
# Add your key to .env file
#
#
# ```bash
# GEMINI_API_KEY=
# ```

# %% [markdown]
# ## Run your first browser agent
#
# ```python
# from browser_use import Agent, ChatGoogle
# from dotenv import load_dotenv
# import asyncio
#
# load_dotenv()
#
# async def main():
#     llm = ChatGoogle(model="gemini-2.5-flash")
#     task = "Find the number 1 post on Show HN"
#     agent = Agent(task=task, llm=llm)
#     history = await agent.run()
#
# if __name__ == "__main__":
#     asyncio.run(main())
# ```

# %% [markdown]
# # Output Format
#
# ## Agent History
#
# The `run()` method returns an `AgentHistoryList` object with the complete execution history:
#
# ```python
# history = await agent.run()
#
# # Access useful information
# history.urls()                    # List of visited URLs
# history.screenshot_paths()        # List of screenshot paths
# history.screenshots()             # List of screenshots as base64 strings
# history.action_names()            # Names of executed actions
# history.extracted_content()       # List of extracted content from all actions
# history.errors()                  # List of errors (with None for steps without errors)
# history.model_actions()           # All actions with their parameters
# history.model_outputs()           # All model outputs from history
# history.last_action()             # Last action in history
#
# # Analysis methods
# history.final_result()            # Get the final extracted content (last step)
# history.is_done()                 # Check if agent completed successfully
# history.is_successful()           # Check if agent completed successfully (returns None if not done)
# history.has_errors()              # Check if any errors occurred
# history.model_thoughts()          # Get the agent's reasoning process (AgentBrain objects)
# history.action_results()          # Get all ActionResult objects from history
# history.action_history()          # Get truncated action history with essential fields
# history.number_of_steps()         # Get the number of steps in the history
# history.total_duration_seconds()  # Get total duration of all steps in seconds
#
# # Structured output (when using output_model_schema)
# history.structured_output         # Property that returns parsed structured output
# ```

# %% [markdown]
# # Web-UI: Easiest Way to Use Browser-Use

# %% [markdown]
# Clone the repository:
# ```bash
# git clone https://github.com/browser-use/web-ui.git
# ```

# %% [markdown]
# Navigate into the directory:
# ```bash
# cd web-ui
# ```

# %% [markdown]
# Create the environment file (web-ui already provides you with a sample environment file):
# ```bash
# cp .env.example .env
# ```
#
# Open the newly created `.env` file in a text editor and add your API keys (like `GOOGLE_API_KEY`). You can also configure other settings as needed.

# %% [markdown]
# https://www.geeksforgeeks.org/devops/docker-tutorial/

# %% [markdown]
# Build the Docker Image:
# ```bash
# docker build -t browser-use-webui .
# ```

# %% [markdown]
# Run the docker container (intel):
# ```bash
# docker run -d --rm \
#   -p 7788:7788 \
#   -p 6080:6080 \
#   --env-file .env \
#   --name browser-use-container \
#   browser-use-webui
# ```

# %% [markdown]
# Run the docker container (arm/apple silicon):
#
# ```bash
# docker run -d --rm \
#   --platform linux/arm64 \
#   -p 7788:7788 \
#   -p 6080:6080 \
#   --env-file .env \
#   --name browser-use-container \
#   browser-use-webui
# ```

# %% [markdown]
# Explanation of the `docker run` flags:
#
#   * `-d`: Detached mode. Runs the container in the background.
#   * `--rm`: Automatically removes the container when it exits.
#   * `-p 7788:7788`: Maps port `7788` on your local machine to port `7788` inside the container for the Web UI.
#   * `-p 6080:6080`: Maps port `6080` on your local machine to port `6080` inside the container for the noVNC browser viewer.
#   * `--env-file .env`: Loads the environment variables from your `.env` file into the container.
#   * `--name browser-use-container`: Assigns a name to your running container for easy management.
#   * `browser-use-webui`: The name of the image you want to run.

# %% [markdown]
# Access the Services:
#
# After running the command, the services will be available at the following URLs on your local machine:
#
#   * **Web-UI:** [http://localhost:7788](https://www.google.com/search?q=http://localhost:7788)
#   * **VNC Viewer (to see the browser):** [http://localhost:6080/vnc.html](https://www.google.com/search?q=http://localhost:6080/vnc.html)

# %% [markdown]
# > Find me the most recent remote data scientist entry levels in India

# %% [markdown]
# # Examples

# %% [markdown]
# ## Basic Search

# %% [markdown]
# ```python
# import asyncio
# import os
# import sys
#
# from dotenv import load_dotenv
#
# load_dotenv()
#
# from browser_use import Agent, ChatGoogleGenerativeAI
#
#
# async def main():
# 	# Instantiate the Google Gemini model
# 	llm = ChatGoogleGenerativeAI(model="gemini-pro")
# 	task = "Search Google for 'what is browser automation' and tell me the top 3 results"
# 	agent = Agent(task=task, llm=llm)
# 	await agent.run()
#
#
# if __name__ == "__main__":
# 	asyncio.run(main())
# ```

# %% [markdown]
# ## Form Filling

# %% [markdown]
# ```python
# import asyncio
# import os
# import sys
#
# from dotenv import load_dotenv
#
# load_dotenv()
#
# # Import the Google Gemini model class
# from browser_use import Agent, ChatGoogleGenerativeAI
#
#
# async def main():
# 	# Initialize the Gemini model
# 	llm = ChatGoogleGenerativeAI(model="gemini-pro")
#
# 	# Define a form filling task
# 	task = """
#     Go to https://httpbin.org/forms/post and fill out the contact form with:
#     - Customer name: John Doe
#     - Telephone: 555-123-4567
#     - Email: john.doe@example.com
#     - Size: Medium
#     - Topping: cheese
#     - Delivery time: now
#     - Comments: This is a test form submission
#
#     Then submit the form and tell me what response you get.
#     """
#
# 	# Create and run the agent
# 	agent = Agent(task=task, llm=llm)
# 	await agent.run()
#
#
# if __name__ == '__main__':
# 	asyncio.run(main())
#
# ```

# %% [markdown]
# ## Data Extraction

# %% [markdown]
# ```python
# import asyncio
# import os
# import sys
#
# from dotenv import load_dotenv
#
# load_dotenv()
#
# # Import the Google Gemini model class
# from browser_use import Agent, ChatGoogleGenerativeAI
#
#
# async def main():
# 	# Initialize the Gemini model
# 	llm = ChatGoogleGenerativeAI(model="gemini-pro")
#
# 	# Define a data extraction task
# 	task = """
#     Go to https://quotes.toscrape.com/ and extract the following information:
#     - The first 5 quotes on the page
#     - The author of each quote
#     - The tags associated with each quote
#
#     Present the information in a clear, structured format like:
#     Quote 1: "[quote text]" - Author: [author name] - Tags: [tag1, tag2, ...]
#     Quote 2: "[quote text]" - Author: [author name] - Tags: [tag1, tag2, ...]
#     etc.
#     """
#
# 	# Create and run the agent
# 	agent = Agent(task=task, llm=llm)
# 	await agent.run()
#
#
# if __name__ == '__main__':
# 	asyncio.run(main())
# ```

# %% [markdown]
# ## Multi-Step Task List

# %% [markdown]
# ```python
#
# import asyncio
# import os
# import sys
# from pathlib import Path
#
#
# from dotenv import load_dotenv
#
# load_dotenv()
#
# # Import the Google Gemini model class
# from browser_use import Agent, ChatGoogleGenerativeAI
#
#
# async def main():
# 	# Initialize the Gemini model
# 	llm = ChatGoogleGenerativeAI(model="gemini-pro")
#
# 	# Define a multi-step task
# 	task = """
#     I want you to research Python web scraping libraries. Here's what I need:
#
#     1. First, search Google for "best Python web scraping libraries 2025"
#     2. Find a reputable article or blog post about this topic
#     3. From that article, extract the top 3 recommended libraries
#     4. For each library, visit its official website or GitHub page
#     5. Extract key information about each library:
#         - Name
#         - Brief description
#         - Main features or advantages
#         - GitHub stars (if available)
#
#     Present your findings in a summary format comparing the three libraries.
#     """
#
# 	# Create and run the agent
# 	agent = Agent(task=task, llm=llm)
# 	await agent.run()
#
#
# if __name__ == '__main__':
# 	asyncio.run(main())
# ```

# %% [markdown]
# # Run Basic Search example in your local machine, and provide history.urls()

# %%
import asyncio
from dotenv import load_dotenv
from browser_use import Agent, ChatGoogle

load_dotenv()

async def run_basic_search_and_print_urls():
	llm = ChatGoogle(model="gemini-2.5-flash")
	task = "Search Google for 'what is browser automation' and tell me the top 3 results"
	agent = Agent(task=task, llm=llm)
	history = await agent.run()
	urls = history.urls()
	print("Visited URLs:")
	for url in urls:
		print(url)
	# Save to file at project root
	with open("visited_urls.txt", "w", encoding="utf-8") as f:
		for u in urls:
			f.write(u + "\n")
	print("\nSaved to visited_urls.txt")

# In Jupyter, use top-level await instead of asyncio.run()
await run_basic_search_and_print_urls()
# Out:
# INFO     [service] Using anonymized telemetry, see https://docs.browser-use.com/development/telemetry.
# INFO     [Agent] 🚀 Task: Search Google for 'what is browser automation' and tell me the top 3 results
# INFO     [service] ────────────────────────────────────────
# INFO     [service] 🔐 To view this run in Browser Use Cloud, authenticate with:
# INFO     [service]     👉  browser-use auth
# INFO     [service]     or: python -m browser_use.cli auth
# INFO     [service] ────────────────────────────────────────
#
# ERROR    [BrowserSession] [LocalBrowserWatchdog] Exception in on_BrowserLaunchEvent:
# Traceback (most recent call last):
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdogs\local_browser_watchdog.py", line 54, in on_BrowserLaunchEvent
#     process, cdp_url = await self._launch_browser()
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py", line 73, in async_wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdogs\local_browser_watchdog.py", line 141, in _launch_browser
#     subprocess = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#     )
#     ^
#   File "C:\ForConda\Lib\asyncio\subprocess.py", line 224, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<3 lines>...
#         stderr=stderr, **kwds)
#         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ForConda\Lib\asyncio\base_events.py", line 1794, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         protocol, popen_args, False, stdin, stdout, stderr,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         bufsize, **kwargs)
#         ^^^^^^^^^^^^^^^^^^
#   File "C:\ForConda\Lib\asyncio\base_events.py", line 539, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
# ERROR    [BrowserSession] 🚌 [LocalBrowserWatchdog.on_BrowserLaunchEvent(#bcd4)]    ❌ Failed (0.00s): NotImplementedError:
# ERROR    [BrowserSession] 🚌 [LocalBrowserWatchdog.on_BrowserLaunchEvent(#bcd4)]    ❌ CDP connected but failed to re-create CDP session after error "NotImplementedError: " in on_BrowserLaunchEvent(BrowserLaunchEvent#bcd4): due to AssertionError: CDP URL not set - browser may not be configured or launched yet
#
# ERROR    [bubus] ❌ EventBus_8b826dab🟢(⏳ 0 | ▶️ 1 | ✅ 1 ➡️ 30 👂) Error in event handler browser_use.browser.watchdog_base.LocalBrowserWatchdog.on_BrowserLaunchEvent(?▶ BrowserLaunchEvent#bcd4 ✅) ->
# NotImplementedError()
# Traceback (most recent call last):
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\service.py", line 1128, in execute_handler
#     result_value: Any = await asyncio.wait_for(handler_task, timeout=event_result.timeout)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ForConda\Lib\asyncio\tasks.py", line 507, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdog_base.py", line 118, in unique_handler
#     result = await actual_handler(event)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py", line 73, in async_wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdogs\local_browser_watchdog.py", line 54, in on_BrowserLaunchEvent
#     process, cdp_url = await self._launch_browser()
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py", line 73, in async_wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdogs\local_browser_watchdog.py", line 141, in _launch_browser
#     subprocess = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#     )
#     ^
#   File "C:\ForConda\Lib\asyncio\subprocess.py", line 224, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<3 lines>...
#         stderr=stderr, **kwds)
#         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ForConda\Lib\asyncio\base_events.py", line 1794, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         protocol, popen_args, False, stdin, stdout, stderr,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         bufsize, **kwargs)
#         ^^^^^^^^^^^^^^^^^^
#   File "C:\ForConda\Lib\asyncio\base_events.py", line 539, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
#
# ERROR    [BrowserSession] 🚌 [BrowserSession.on_BrowserStartEvent(#54dc)]           ❌ Failed (0.03s): NotImplementedError:
# ERROR    [BrowserSession] 🚌 [BrowserSession.on_BrowserStartEvent(#54dc)]           ❌ CDP connected but failed to re-create CDP session after error "NotImplementedError: " in on_BrowserStartEvent(BrowserStartEvent#54dc): due to AssertionError: CDP URL not set - browser may not be configured or launched yet
#
# ERROR    [bubus] ❌ EventBus_8b826dab🟢(⏳ 1 | ▶️ 0 | ✅ 2 ➡️ 30 👂) Error in event handler browser_use.browser.watchdog_base.BrowserSession.on_BrowserStartEvent(?▶ BrowserStartEvent#54dc ✅) ->
# NotImplementedError()
# Traceback (most recent call last):
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\service.py", line 1128, in execute_handler
#     result_value: Any = await asyncio.wait_for(handler_task, timeout=event_result.timeout)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ForConda\Lib\asyncio\tasks.py", line 507, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdog_base.py", line 118, in unique_handler
#     result = await actual_handler(event)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py", line 73, in async_wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\session.py", line 539, in on_BrowserStartEvent
#     BrowserLaunchResult, await launch_event.event_result(raise_if_none=True, raise_if_any=True)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py", line 574, in event_result
#     valid_results = await self.event_results_filtered(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         timeout=timeout, include=include, raise_if_any=raise_if_any, raise_if_none=raise_if_none
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py", line 516, in event_results_filtered
#     raise original_error
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py", line 490, in event_results_filtered
#     await event_result
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py", line 889, in wait_for_handler_to_complete_and_return_result
#     raise self.error if isinstance(self.error, BaseException) else Exception(self.error)  # pyright: ignore[reportUnnecessaryIsInstance]
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\service.py", line 1070, in _execute_handlers
#     await self.execute_handler(event, handler, timeout=timeout)
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\service.py", line 1128, in execute_handler
#     result_value: Any = await asyncio.wait_for(handler_task, timeout=event_result.timeout)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ForConda\Lib\asyncio\tasks.py", line 507, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdog_base.py", line 118, in unique_handler
#     result = await actual_handler(event)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py", line 73, in async_wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdogs\local_browser_watchdog.py", line 54, in on_BrowserLaunchEvent
#     process, cdp_url = await self._launch_browser()
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py", line 73, in async_wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdogs\local_browser_watchdog.py", line 141, in _launch_browser
#     subprocess = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#     )
#     ^
#   File "C:\ForConda\Lib\asyncio\subprocess.py", line 224, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<3 lines>...
#         stderr=stderr, **kwds)
#         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ForConda\Lib\asyncio\base_events.py", line 1794, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         protocol, popen_args, False, stdin, stdout, stderr,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         bufsize, **kwargs)
#         ^^^^^^^^^^^^^^^^^^
#   File "C:\ForConda\Lib\asyncio\base_events.py", line 539, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
#
# ERROR    [Agent] Agent run failed with exception:
# Traceback (most recent call last):
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\agent\service.py", line 1465, in run
#     await self.browser_session.start()
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py", line 73, in async_wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\session.py", line 462, in start
#     await start_event.event_result(raise_if_any=True, raise_if_none=False)
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py", line 574, in event_result
#     valid_results = await self.event_results_filtered(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         timeout=timeout, include=include, raise_if_any=raise_if_any, raise_if_none=raise_if_none
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py", line 516, in event_results_filtered
#     raise original_error
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py", line 490, in event_results_filtered
#     await event_result
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py", line 889, in wait_for_handler_to_complete_and_return_result
#     raise self.error if isinstance(self.error, BaseException) else Exception(self.error)  # pyright: ignore[reportUnnecessaryIsInstance]
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\service.py", line 1070, in _execute_handlers
#     await self.execute_handler(event, handler, timeout=timeout)
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\service.py", line 1128, in execute_handler
#     result_value: Any = await asyncio.wait_for(handler_task, timeout=event_result.timeout)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ForConda\Lib\asyncio\tasks.py", line 507, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdog_base.py", line 118, in unique_handler
#     result = await actual_handler(event)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py", line 73, in async_wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\session.py", line 539, in on_BrowserStartEvent
#     BrowserLaunchResult, await launch_event.event_result(raise_if_none=True, raise_if_any=True)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py", line 574, in event_result
#     valid_results = await self.event_results_filtered(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         timeout=timeout, include=include, raise_if_any=raise_if_any, raise_if_none=raise_if_none
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py", line 516, in event_results_filtered
#     raise original_error
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py", line 490, in event_results_filtered
#     await event_result
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py", line 889, in wait_for_handler_to_complete_and_return_result
#     raise self.error if isinstance(self.error, BaseException) else Exception(self.error)  # pyright: ignore[reportUnnecessaryIsInstance]
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\service.py", line 1070, in _execute_handlers
#     await self.execute_handler(event, handler, timeout=timeout)
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\service.py", line 1128, in execute_handler
#     result_value: Any = await asyncio.wait_for(handler_task, timeout=event_result.timeout)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ForConda\Lib\asyncio\tasks.py", line 507, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdog_base.py", line 118, in unique_handler
#     result = await actual_handler(event)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py", line 73, in async_wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdogs\local_browser_watchdog.py", line 54, in on_BrowserLaunchEvent
#     process, cdp_url = await self._launch_browser()
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py", line 73, in async_wrapper
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdogs\local_browser_watchdog.py", line 141, in _launch_browser
#     subprocess = await asyncio.create_subprocess_exec(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#     )
#     ^
#   File "C:\ForConda\Lib\asyncio\subprocess.py", line 224, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<3 lines>...
#         stderr=stderr, **kwds)
#         ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ForConda\Lib\asyncio\base_events.py", line 1794, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         protocol, popen_args, False, stdin, stdout, stderr,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         bufsize, **kwargs)
#         ^^^^^^^^^^^^^^^^^^
#   File "C:\ForConda\Lib\asyncio\base_events.py", line 539, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
# ERROR    [BrowserSession] 🚌 [StorageStateWatchdog.on_SaveStorageStateEvent(#e84a)] ❌ Failed (0.00s): AssertionError: CDP URL not set - browser may not be configured or launched yet
# ERROR    [BrowserSession] 🚌 [StorageStateWatchdog.on_SaveStorageStateEvent(#e84a)] ❌ CDP connected but failed to re-create CDP session after error "AssertionError: CDP URL not set - browser may not be configured or launched yet" in on_SaveStorageStateEvent(SaveStorageStateEvent#e84a): due to AssertionError: CDP URL not set - browser may not be configured or launched yet
#
# ERROR    [bubus] ❌ EventBus_8b826dab🟢(⏳ 0 | ▶️ 0 | ✅ 4 ➡️ 30 👂) Error in event handler browser_use.browser.watchdog_base.StorageStateWatchdog.on_SaveStorageStateEvent(?▶ SaveStorageStateEvent#e84a ✅) ->
# AssertionError(CDP URL not set - browser may not be configured or launched yet)
# Traceback (most recent call last):
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\service.py", line 1128, in execute_handler
#     result_value: Any = await asyncio.wait_for(handler_task, timeout=event_result.timeout)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\ForConda\Lib\asyncio\tasks.py", line 507, in wait_for
#     return await fut
#            ^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdog_base.py", line 118, in unique_handler
#     result = await actual_handler(event)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdogs\storage_state_watchdog.py", line 73, in on_SaveStorageStateEvent
#     await self._save_storage_state(path)
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdogs\storage_state_watchdog.py", line 168, in _save_storage_state
#     assert await self.browser_session.get_or_create_cdp_session(target_id=None, new_socket=False)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\session.py", line 1002, in get_or_create_cdp_session
#     assert self.cdp_url is not None, 'CDP URL not set - browser may not be configured or launched yet'
#            ^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: CDP URL not set - browser may not be configured or launched yet
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[1], line 23
#      20 	print("\nSaved to visited_urls.txt")
#      22 # In Jupyter, use top-level await instead of asyncio.run()
# ---> 23 await run_basic_search_and_print_urls()
#
# Cell In[1], line 11, in run_basic_search_and_print_urls()
#       9 task = "Search Google for 'what is browser automation' and tell me the top 3 results"
#      10 agent = Agent(task=task, llm=llm)
# ---> 11 history = await agent.run()
#      12 urls = history.urls()
#      13 print("Visited URLs:")
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py:73, in _create_no_op_decorator.<locals>.decorator.<locals>.async_wrapper(*args, **kwargs)
#      71 @wraps(func)
#      72 async def async_wrapper(*args, **kwargs):
# ---> 73 	return await func(*args, **kwargs)
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\utils.py:363, in time_execution_async.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     360 @wraps(func)
#     361 async def wrapper(*args: P.args, **kwargs: P.kwargs) -> R:
#     362 	start_time = time.time()
# --> 363 	result = await func(*args, **kwargs)
#     364 	execution_time = time.time() - start_time
#     365 	# Only log if execution takes more than 0.25 seconds to avoid spamming the logs
#     366 	# you can lower this threshold locally when you're doing dev work to performance optimize stuff
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\agent\service.py:1569, in Agent.run(self, max_steps, on_step_start, on_step_end)
#    1567 	self.logger.error(f'Agent run failed with exception: {e}', exc_info=True)
#    1568 	agent_run_error = str(e)
# -> 1569 	raise e
#    1571 finally:
#    1572 	# Log token usage summary
#    1573 	await self.token_cost_service.log_usage_summary()
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\agent\service.py:1465, in Agent.run(self, max_steps, on_step_start, on_step_end)
#    1462 	self.eventbus.dispatch(CreateAgentTaskEvent.from_agent(self))
#    1464 # Start browser session and attach watchdogs
# -> 1465 await self.browser_session.start()
#    1467 await self._execute_initial_actions()
#    1468 # Log startup message on first step (only if we haven't already done steps)
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py:73, in _create_no_op_decorator.<locals>.decorator.<locals>.async_wrapper(*args, **kwargs)
#      71 @wraps(func)
#      72 async def async_wrapper(*args, **kwargs):
# ---> 73 	return await func(*args, **kwargs)
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\session.py:462, in BrowserSession.start(self)
#     460 await start_event
#     461 # Ensure any exceptions from the event handler are propagated
# --> 462 await start_event.event_result(raise_if_any=True, raise_if_none=False)
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py:574, in BaseEvent.event_result(self, timeout, include, raise_if_any, raise_if_none)
#     566 async def event_result(
#     567     self,
#     568     timeout: float | None = None,
#    (...)    571     raise_if_none: bool = True,
#     572 ) -> T_EventResultType | None:
#     573     """Get the first non-None result from the event handlers"""
# --> 574     valid_results = await self.event_results_filtered(
#     575         timeout=timeout, include=include, raise_if_any=raise_if_any, raise_if_none=raise_if_none
#     576     )
#     577     results = list(valid_results.values())
#     578     return cast(T_EventResultType | None, results[0].result) if results else None
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py:516, in BaseEvent.event_results_filtered(self, timeout, include, raise_if_any, raise_if_none)
#     514 # Re-raise the original exception to preserve its type and structured data
#     515 if isinstance(original_error, BaseException):
# --> 516     raise original_error
#     517 else:
#     518     # Fallback for non-exception errors (shouldn't happen in practice)
#     519     raise Exception(str(original_error))
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py:490, in BaseEvent.event_results_filtered(self, timeout, include, raise_if_any, raise_if_none)
#     488 for event_result in self.event_results.values():
#     489     try:
# --> 490         await event_result
#     491     except Exception:
#     492         # Ignore exceptions here - we'll handle them based on raise_if_any below
#     493         pass
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py:889, in EventResult.__await__.<locals>.wait_for_handler_to_complete_and_return_result()
#     884     raise TimeoutError(
#     885         f'Event handler {self.eventbus_name}.{self.handler_name}(#{self.event_id[-4:]}) timed out after {self.timeout}s'
#     886     )
#     888 if self.status == 'error' and self.error:
# --> 889     raise self.error if isinstance(self.error, BaseException) else Exception(self.error)  # pyright: ignore[reportUnnecessaryIsInstance]
#     891 return self.result
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\service.py:1070, in EventBus._execute_handlers(self, event, handlers, timeout)
#    1068 for handler_id, handler in applicable_handlers.items():
#    1069     try:
# -> 1070         await self.execute_handler(event, handler, timeout=timeout)
#    1071     except Exception as e:
#    1072         # Error already logged and recorded in execute_handler
#    1073         logger.debug(
#    1074             f'❌ {self} Handler {get_handler_name(handler)}#{str(id(handler))[-4:]}({event}) failed with {type(e).__name__}: {e}'
#    1075         )
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\service.py:1128, in EventBus.execute_handler(self, event, handler, timeout)
#    1126     handler_task = asyncio.create_task(handler(event))  # type: ignore
#    1127     # This allows us to process child events when the handler awaits them
# -> 1128     result_value: Any = await asyncio.wait_for(handler_task, timeout=event_result.timeout)
#    1129 elif inspect.isfunction(handler) or inspect.ismethod(handler):
#    1130     # If handler function is sync function, run it directly in the main thread
#    1131     # This blocks but ensures we have access to the event loop, dont run it in a subthread!
#    1132     result_value: Any = handler(event)
#
# File C:\ForConda\Lib\asyncio\tasks.py:507, in wait_for(fut, timeout)
#     504         raise TimeoutError from exc
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdog_base.py:118, in BaseWatchdog.attach_handler_to_session.<locals>.make_unique_handler.<locals>.unique_handler(event)
#     112 browser_session.logger.debug(
#     113 	f'{cyan}🚌 {watchdog_and_handler_str} ⏳ Starting...      {reset} {parent} {grandparent}'
#     114 )
#     116 try:
#     117 	# **EXECUTE THE EVENT HANDLER FUNCTION**
# --> 118 	result = await actual_handler(event)
#     120 	if isinstance(result, Exception):
#     121 		raise result
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py:73, in _create_no_op_decorator.<locals>.decorator.<locals>.async_wrapper(*args, **kwargs)
#      71 @wraps(func)
#      72 async def async_wrapper(*args, **kwargs):
# ---> 73 	return await func(*args, **kwargs)
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\session.py:539, in BrowserSession.on_BrowserStartEvent(self, event)
#     535 	await launch_event
#     537 	# Get the CDP URL from LocalBrowserWatchdog handler result
#     538 	launch_result: BrowserLaunchResult = cast(
# --> 539 		BrowserLaunchResult, await launch_event.event_result(raise_if_none=True, raise_if_any=True)
#     540 	)
#     541 	self.browser_profile.cdp_url = launch_result.cdp_url
#     542 else:
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py:574, in BaseEvent.event_result(self, timeout, include, raise_if_any, raise_if_none)
#     566 async def event_result(
#     567     self,
#     568     timeout: float | None = None,
#    (...)    571     raise_if_none: bool = True,
#     572 ) -> T_EventResultType | None:
#     573     """Get the first non-None result from the event handlers"""
# --> 574     valid_results = await self.event_results_filtered(
#     575         timeout=timeout, include=include, raise_if_any=raise_if_any, raise_if_none=raise_if_none
#     576     )
#     577     results = list(valid_results.values())
#     578     return cast(T_EventResultType | None, results[0].result) if results else None
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py:516, in BaseEvent.event_results_filtered(self, timeout, include, raise_if_any, raise_if_none)
#     514 # Re-raise the original exception to preserve its type and structured data
#     515 if isinstance(original_error, BaseException):
# --> 516     raise original_error
#     517 else:
#     518     # Fallback for non-exception errors (shouldn't happen in practice)
#     519     raise Exception(str(original_error))
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py:490, in BaseEvent.event_results_filtered(self, timeout, include, raise_if_any, raise_if_none)
#     488 for event_result in self.event_results.values():
#     489     try:
# --> 490         await event_result
#     491     except Exception:
#     492         # Ignore exceptions here - we'll handle them based on raise_if_any below
#     493         pass
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\models.py:889, in EventResult.__await__.<locals>.wait_for_handler_to_complete_and_return_result()
#     884     raise TimeoutError(
#     885         f'Event handler {self.eventbus_name}.{self.handler_name}(#{self.event_id[-4:]}) timed out after {self.timeout}s'
#     886     )
#     888 if self.status == 'error' and self.error:
# --> 889     raise self.error if isinstance(self.error, BaseException) else Exception(self.error)  # pyright: ignore[reportUnnecessaryIsInstance]
#     891 return self.result
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\service.py:1070, in EventBus._execute_handlers(self, event, handlers, timeout)
#    1068 for handler_id, handler in applicable_handlers.items():
#    1069     try:
# -> 1070         await self.execute_handler(event, handler, timeout=timeout)
#    1071     except Exception as e:
#    1072         # Error already logged and recorded in execute_handler
#    1073         logger.debug(
#    1074             f'❌ {self} Handler {get_handler_name(handler)}#{str(id(handler))[-4:]}({event}) failed with {type(e).__name__}: {e}'
#    1075         )
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\bubus\service.py:1128, in EventBus.execute_handler(self, event, handler, timeout)
#    1126     handler_task = asyncio.create_task(handler(event))  # type: ignore
#    1127     # This allows us to process child events when the handler awaits them
# -> 1128     result_value: Any = await asyncio.wait_for(handler_task, timeout=event_result.timeout)
#    1129 elif inspect.isfunction(handler) or inspect.ismethod(handler):
#    1130     # If handler function is sync function, run it directly in the main thread
#    1131     # This blocks but ensures we have access to the event loop, dont run it in a subthread!
#    1132     result_value: Any = handler(event)
#
# File C:\ForConda\Lib\asyncio\tasks.py:507, in wait_for(fut, timeout)
#     504         raise TimeoutError from exc
#     506 async with timeouts.timeout(timeout):
# --> 507     return await fut
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdog_base.py:118, in BaseWatchdog.attach_handler_to_session.<locals>.make_unique_handler.<locals>.unique_handler(event)
#     112 browser_session.logger.debug(
#     113 	f'{cyan}🚌 {watchdog_and_handler_str} ⏳ Starting...      {reset} {parent} {grandparent}'
#     114 )
#     116 try:
#     117 	# **EXECUTE THE EVENT HANDLER FUNCTION**
# --> 118 	result = await actual_handler(event)
#     120 	if isinstance(result, Exception):
#     121 		raise result
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py:73, in _create_no_op_decorator.<locals>.decorator.<locals>.async_wrapper(*args, **kwargs)
#      71 @wraps(func)
#      72 async def async_wrapper(*args, **kwargs):
# ---> 73 	return await func(*args, **kwargs)
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdogs\local_browser_watchdog.py:54, in LocalBrowserWatchdog.on_BrowserLaunchEvent(self, event)
#      51 self.logger.debug('[LocalBrowserWatchdog] Received BrowserLaunchEvent, launching local browser...')
#      53 # self.logger.debug('[LocalBrowserWatchdog] Calling _launch_browser...')
# ---> 54 process, cdp_url = await self._launch_browser()
#      55 self._subprocess = process
#      56 # self.logger.debug(f'[LocalBrowserWatchdog] _launch_browser returned: process={process}, cdp_url={cdp_url}')
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\observability.py:73, in _create_no_op_decorator.<locals>.decorator.<locals>.async_wrapper(*args, **kwargs)
#      71 @wraps(func)
#      72 async def async_wrapper(*args, **kwargs):
# ---> 73 	return await func(*args, **kwargs)
#
# File d:\21days21aiprojects\L20_Web_Automation_on_Autopilot_Building_an_AI_Browser_Agent\.venv\Lib\site-packages\browser_use\browser\watchdogs\local_browser_watchdog.py:141, in LocalBrowserWatchdog._launch_browser(self, max_retries)
#     139 # Launch browser subprocess directly
#     140 self.logger.debug(f'[LocalBrowserWatchdog] 🚀 Launching browser subprocess with {len(launch_args)} args...')
# --> 141 subprocess = await asyncio.create_subprocess_exec(
#     142 	browser_path,
#     143 	*launch_args,
#     144 	stdout=asyncio.subprocess.PIPE,
#     145 	stderr=asyncio.subprocess.PIPE,
#     146 )
#     147 self.logger.debug(
#     148 	f'[LocalBrowserWatchdog] 🎭 Browser running with browser_pid= {subprocess.pid} 🔗 listening on CDP port :{debug_port}'
#     149 )
#     151 # Convert to psutil.Process
#
# File C:\ForConda\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     221 loop = events.get_running_loop()
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File C:\ForConda\Lib\asyncio\base_events.py:1794, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1792     debug_log = f'execute program {program!r}'
#    1793     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1794 transport = await self._make_subprocess_transport(
#    1795     protocol, popen_args, False, stdin, stdout, stderr,
#    1796     bufsize, **kwargs)
#    1797 if self._debug and debug_log is not None:
#    1798     logger.info('%s: %r', debug_log, transport)
#
# File C:\ForConda\Lib\asyncio\base_events.py:539, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     535 async def _make_subprocess_transport(self, protocol, args, shell,
#     536                                      stdin, stdout, stderr, bufsize,
#     537                                      extra=None, **kwargs):
#     538     """Create subprocess transport."""
# --> 539     raise NotImplementedError
#
# NotImplementedError:
